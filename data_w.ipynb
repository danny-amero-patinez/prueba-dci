# %%
import pandas as pd
import numpy as np

# %%
adress_train = "../prueba-dci/filter_dc3/datosEntrenamiento.csv"
adress_prueba = "../prueba-dci/filter_dc3/datosPrueba.csv"
adress_validacion = "../prueba-dci/filter_dc3/datosValidacion.csv"

data_train = pd.read_csv(adress_train)
data_test = pd.read_csv(adress_prueba)

# %%
data_train.tail()
# Out:
#       92  115  120   94  84  102  106   79  84.1  102.1  ...  104.1  88  121  \
# 4498  80  107  122   96  76  107  118   96    84    116  ...     96  74   83
# 4499  84  116  128  103  92  116  133  103    84    112  ...     85  74   83
# 4500  60   83   96   85  64   87  100   88    64     83  ...     92  66   87
# 4501  56   68   87   74  60   71   91   81    60     64  ...     74  59   83
# 4502  60   71   91   81  60   64  104   99    56     64  ...     74  59   83
#
#       128  100  84.3  107  113  87  1
# 4498  108   89    66   71  100  85  6
# 4499  104   92    78   96  112  96  6
# 4500  108   89    63   83  104  85  6
# 4501   92   74    59   83   92  70  3
# 4502   92   70    63   79  108  92  3
#
# [5 rows x 37 columns]

# %%
data_test.head()
# Out:
#    76   94   98  76.1  72   85   90  72.1  68  85.1  ...  62  71.2  79.1  \
# 0  68   89   86    72  68   85   90    76  68    94  ...  67    71    75
# 1  92  115  115    94  92  111  120    91  84   106  ...  92    93   107
# 2  84  106  111    87  84   98  111    87  84    98  ...  92    93   107
# 3  88  111  115    91  88  111  120    87  88   111  ...  87    88   107
# 4  84  102  106    83  88  111  111    87  88   111  ...  79    88    95
#
#    85.2  62.1  67.3   75  85.3  62.2  2
# 0    81    62    67   75    85    71  2
# 1   109    92    93  111   113    92  1
# 2   113    87    93  107   113    87  1
# 3   109    87    88  107   109    87  1
# 4   100    79    88   95   100    83  1
#
# [5 rows x 37 columns]

# %%
data_test.rows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-60a88a2734b5> in <module>
# ----> 1 data_test.rows()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'
