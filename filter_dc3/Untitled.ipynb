# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
import_train = "datosEntrenamiento.csv"
import_prueba = "datosPrueba.csv"
import_validacion = "datosValidacion.csv"


data_train = pd.read_csv(import_train)
data_prueba = pd.read_csv(import_prueba)
data_vali = pd.read_csv(import_validacion)

# %%
reg = linear_model.LogisticRegression()

# %%
data_train
# Out:
#       92  115  120   94  84  102  106   79  84.1  102.1  ...  104.1  88  121  \
# 0     84  102  102   83  80  102  102   79    84     94  ...     87  84   99
# 1     84   94  102   79  80   94   98   76    80    102  ...     79  84  103
# 2     80   94   98   76  80  102  102   79    76    102  ...     79  79  107
# 3     76  102  106   83  76  102  106   87    80     98  ...     87  79  103
# 4     76  102  106   87  80   98  106   79    76     94  ...     83  79  103
# ...   ..  ...  ...  ...  ..  ...  ...  ...   ...    ...  ...    ...  ..  ...
# 4498  80  107  122   96  76  107  118   96    84    116  ...     96  74   83
# 4499  84  116  128  103  92  116  133  103    84    112  ...     85  74   83
# 4500  60   83   96   85  64   87  100   88    64     83  ...     92  66   87
# 4501  56   68   87   74  60   71   91   81    60     64  ...     74  59   83
# 4502  60   71   91   81  60   64  104   99    56     64  ...     74  59   83
#
#       128  100  84.3  107  113  87  1
# ...

# %%
arreglox = data_train[data_train.columns[:-1]].as_matrix()
arregloy = data_train[data_train.columns[-1]].as_matrix()
# Out:
# /home/javier/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# /home/javier/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
arreglox
# Out:
# array([[ 84, 102, 102, ...,  99, 104,  79],
#        [ 84,  94, 102, ..., 107, 109,  87],
#        [ 80,  94,  98, ..., 107, 109,  87],
#        ...,
#        [ 60,  83,  96, ...,  83, 104,  85],
#        [ 56,  68,  87, ...,  83,  92,  70],
#        [ 60,  71,  91, ...,  79, 108,  92]])

# %%
arregloy
# Out:
# array([1, 1, 1, ..., 6, 3, 3])

# %%
x_train,x_prueba,y_train,y_prueba = train_test_split(arreglox,arregloy)

# %%
reg.fit(x_train,y_train)
# Out:
# /home/javier/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/javier/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
reg.score(x_prueba,y_prueba)
# Out:
# 0.8179396092362344
